# %%
import pickle

# %%
load_model = pickle.load(open("final_model_SLR.sav", 'rb'))
result = load_model.predict([[13]])
# Out:
# C:\Users\Sanjay\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
result
# Out:
# array([[148460.78806172]])

# %%
load_model = pickle.load(open("final_model_SLR.sav", 'rb'))
result = load_model.predict([[0]])
# Out:
# C:\Users\Sanjay\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
print(result) #Since the input is 0, it will returns the origin value as a result.
# Out:
# [[26777.3913412]]
