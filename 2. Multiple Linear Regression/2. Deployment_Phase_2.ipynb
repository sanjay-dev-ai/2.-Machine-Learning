# %%
import pickle

# %%
load_model = pickle.load(open('finalized_multi_model_linear.sav', 'rb'))
result = load_model.predict([[8757,8078,7895,1,0]])
# Out:
# C:\Users\Sanjay\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
result
# Out:
# array([[50280.73719978]])

# %%
result = load_model.predict([[int(input("Enter R&D Spend:")),
                              int(input("Enter Administration Spend:")),
                              int(input("Enter Marketing Spend:")),1,0]])
# Out:
# Enter R&D Spend: 8757
# Enter Administration Spend: 8078
# Enter Marketing Spend: 7895
# C:\Users\Sanjay\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
print("Profit is:",result)
# Out:
# Profit is: [[50280.73719978]]
